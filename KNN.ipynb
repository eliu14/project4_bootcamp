# %%
# Import findspark
import findspark
findspark.init()

# %%
# Start Spark session
from pyspark.sql import SparkSession
from sklearn.decomposition import PCA
spark = SparkSession.builder.appName("knnLearning").getOrCreate()

# %%
from pyspark import SparkFiles
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
file = "./Resources/online_shoppers_intention.csv"
spark.sparkContext.addFile(file)
df = spark.read.csv(SparkFiles.get("online_shoppers_intention.csv"), sep=",", header=True)

# Show DataFrame
df.show()
# Out:
# +--------------+-----------------------+-------------+----------------------+--------------+-----------------------+-----------+-----------+----------+----------+-----+----------------+-------+------+-----------+-----------------+-------+-------+
# |Administrative|Administrative_Duration|Informational|Informational_Duration|ProductRelated|ProductRelated_Duration|BounceRates|  ExitRates|PageValues|SpecialDay|Month|OperatingSystems|Browser|Region|TrafficType|      VisitorType|Weekend|Revenue|
# +--------------+-----------------------+-------------+----------------------+--------------+-----------------------+-----------+-----------+----------+----------+-----+----------------+-------+------+-----------+-----------------+-------+-------+
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|         0|  Feb|               1|      1|     1|          1|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             2|                     64|          0|        0.1|         0|         0|  Feb|               2|      2|     1|          2|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|         0|  Feb|               4|      1|     9|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             2|            2.666666667|       0.05|       0.14|         0|         0|  Feb|               3|      2|     2|          4|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|            10|                  627.5|       0.02|       0.05|         0|         0|  Feb|               3|      3|     1|          4|Returning_Visitor|   TRUE|  FALSE|
# |             0|                      0|            0|                     0|            19|            154.2166667|0.015789474|0.024561404|         0|         0|  Feb|               2|      2|     1|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|       0.4|  Feb|               2|      4|     3|          3|Returning_Visitor|  FALSE|  FALSE|
# |             1|                      0|            0|                     0|             0|                      0|        0.2|        0.2|         0|         0|  Feb|               1|      2|     1|          5|Returning_Visitor|   TRUE|  FALSE|
# |             0|                      0|            0|                     0|             2|                     37|          0|        0.1|         0|       0.8|  Feb|               2|      2|     2|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             3|                    738|          0|0.022222222|         0|       0.4|  Feb|               2|      4|     1|          2|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             3|                    395|          0|0.066666667|         0|         0|  Feb|               1|      1|     3|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|            16|                 407.75|    0.01875|0.025833333|         0|       0.4|  Feb|               1|      1|     4|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             7|                  280.5|          0|0.028571429|         0|         0|  Feb|               1|      1|     1|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             6|                     98|          0|0.066666667|         0|         0|  Feb|               2|      5|     1|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             2|                     68|          0|        0.1|         0|         0|  Feb|               3|      2|     3|          3|Returning_Visitor|  FALSE|  FALSE|
# |             2|                     53|            0|                     0|            23|            1668.285119|0.008333333|0.016312636|         0|         0|  Feb|               1|      1|     9|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|         0|  Feb|               1|      1|     4|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|            13|            334.9666667|          0|0.007692308|         0|         0|  Feb|               1|      1|     1|          4|Returning_Visitor|   TRUE|  FALSE|
# |             0|                      0|            0|                     0|             2|                     32|          0|        0.1|         0|         0|  Feb|               2|      2|     1|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|            20|            2981.166667|          0|       0.01|         0|         0|  Feb|               2|      4|     4|          4|Returning_Visitor|  FALSE|  FALSE|
# +--------------+-----------------------+-------------+----------------------+--------------+-----------------------+-----------+-----------+----------+----------+-----+----------------+-------+------+-----------+-----------------+-------+-------+
# only showing top 20 rows

# %%
df.columns
# Out:
# ['Administrative',
#  'Administrative_Duration',
#  'Informational',
#  'Informational_Duration',
#  'ProductRelated',
#  'ProductRelated_Duration',
#  'BounceRates',
#  'ExitRates',
#  'PageValues',
#  'SpecialDay',
#  'Month',
#  'OperatingSystems',
#  'Browser',
#  'Region',
#  'TrafficType',
#  'VisitorType',
#  'Weekend',
#  'Revenue']

# %%
df.createOrReplaceTempView("online_shoppers_intention")

# %%
spark.sql(
"""
SELECT 
* 
FROM 
online_shoppers_intention 
LIMIT 10
""").show()
# Out:
# +--------------+-----------------------+-------------+----------------------+--------------+-----------------------+-----------+-----------+----------+----------+-----+----------------+-------+------+-----------+-----------------+-------+-------+
# |Administrative|Administrative_Duration|Informational|Informational_Duration|ProductRelated|ProductRelated_Duration|BounceRates|  ExitRates|PageValues|SpecialDay|Month|OperatingSystems|Browser|Region|TrafficType|      VisitorType|Weekend|Revenue|
# +--------------+-----------------------+-------------+----------------------+--------------+-----------------------+-----------+-----------+----------+----------+-----+----------------+-------+------+-----------+-----------------+-------+-------+
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|         0|  Feb|               1|      1|     1|          1|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             2|                     64|          0|        0.1|         0|         0|  Feb|               2|      2|     1|          2|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|         0|  Feb|               4|      1|     9|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             2|            2.666666667|       0.05|       0.14|         0|         0|  Feb|               3|      2|     2|          4|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|            10|                  627.5|       0.02|       0.05|         0|         0|  Feb|               3|      3|     1|          4|Returning_Visitor|   TRUE|  FALSE|
# |             0|                      0|            0|                     0|            19|            154.2166667|0.015789474|0.024561404|         0|         0|  Feb|               2|      2|     1|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             1|                      0|        0.2|        0.2|         0|       0.4|  Feb|               2|      4|     3|          3|Returning_Visitor|  FALSE|  FALSE|
# |             1|                      0|            0|                     0|             0|                      0|        0.2|        0.2|         0|         0|  Feb|               1|      2|     1|          5|Returning_Visitor|   TRUE|  FALSE|
# |             0|                      0|            0|                     0|             2|                     37|          0|        0.1|         0|       0.8|  Feb|               2|      2|     2|          3|Returning_Visitor|  FALSE|  FALSE|
# |             0|                      0|            0|                     0|             3|                    738|          0|0.022222222|         0|       0.4|  Feb|               2|      4|     1|          2|Returning_Visitor|  FALSE|  FALSE|
# +--------------+-----------------------+-------------+----------------------+--------------+-----------------------+-----------+-----------+----------+----------+-----+----------------+-------+------+-----------+-----------------+-------+-------+

# %%
df = df.toPandas()
y = df["Revenue"]
X = df.drop(columns=["Revenue"])

# %%
X[:5]
# Out:
#   Administrative Administrative_Duration  ...        VisitorType Weekend
# 0              0                       0  ...  Returning_Visitor   FALSE
# 1              0                       0  ...  Returning_Visitor   FALSE
# 2              0                       0  ...  Returning_Visitor   FALSE
# 3              0                       0  ...  Returning_Visitor   FALSE
# 4              0                       0  ...  Returning_Visitor    TRUE
#
# [5 rows x 17 columns]

# %%
y[:5]
# Out:
# 0    FALSE
# 1    FALSE
# 2    FALSE
# 3    FALSE
# 4    FALSE
# Name: Revenue, dtype: object

# %%
pca_cols = [col for col in X.columns if col not in ["ProductRelated", "ProductRelated_Duration",
                                                     "SpecialDay", "Month",	"OperatingSystems",	"Browser", "Region",	
                                                     "TrafficType",	"VisitorType", "Weekend"
                                                     ]]
pca_df = X[pca_cols]
scaler = StandardScaler()
pca_scaled = scaler.fit_transform(pca_df)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(pca_scaled)
pca.explained_variance_ratio_
# Out:
# array([0.37119637, 0.22898014])

# %%
pca_cols = [f'PC{i+1}' for i in range(X_pca.shape[1])]
df_pca = pd.DataFrame(X_pca, columns=pca_cols, index=df.index)

# %%
cols_to_keep = ["ProductRelated", "ProductRelated_Duration",
                "SpecialDay", "Month",	"OperatingSystems",	"Browser", "Region",	
                "TrafficType",	"VisitorType", "Weekend"
              ] 
X = pd.concat([df_pca, X[cols_to_keep]], axis=1)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head(5)
# Out:
#         PC1       PC2  ...  VisitorType_Returning_Visitor  Weekend_TRUE
# 0  3.715813  3.166276  ...                           True         False
# 1  1.108562 -0.105538  ...                           True         False
# 2  3.715813  3.166276  ...                           True         False
# 3  1.898920  0.868236  ...                           True         False
# 4  0.815107 -0.401637  ...                           True          True
#
# [5 rows x 9925 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Train KNN with custom weights
model = KNeighborsClassifier(n_neighbors=3, weights="distance")

# %%
# Train the model
model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
# Create predictions
y_pred = model.predict(X_test_scaled)

# Review the predictions
y_pred
# Out:
# array(['FALSE', 'FALSE', 'FALSE', ..., 'FALSE', 'FALSE', 'FALSE'],
#       dtype=object)

# %%
# Print confusion matrix
confusion_matrix(y_pred,y_test)
# Out:
# array([[2046,  379],
#        [  38,    3]], dtype=int64)

# %%
# Print classification report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        FALSE       0.98      0.84      0.91      2425
#         TRUE       0.01      0.07      0.01        41
#
#     accuracy                           0.83      2466
#    macro avg       0.49      0.46      0.46      2466
# weighted avg       0.97      0.83      0.89      2466

# %%
# tensorflow neural network deep learning
from sklearn.metrics import accuracy_score
import tensorflow as tf

# Check if TensorFlow can access GPU hardware acceleration
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
else:
    print("No GPU found, using CPU for training.")

# %%
tf_df = pd.read_csv("./Resources/online_shoppers_intention.csv")
tf_df.head()
# Out:
#    Administrative  Administrative_Duration  ...  Weekend  Revenue
# 0               0                      0.0  ...    False    False
# 1               0                      0.0  ...    False    False
# 2               0                      0.0  ...    False    False
# 3               0                      0.0  ...    False    False
# 4               0                      0.0  ...     True    False
#
# [5 rows x 18 columns]

# %%
# tf_df.drop(columns=["Administrative", "Administrative_Duration", "Informational", "Informational_Duration",
#                     "BounceRates", "ExitRates", "PageValues"], inplace=True)

# %%
tf_df.nunique()
# Out:
# Administrative               27
# Administrative_Duration    3335
# Informational                17
# Informational_Duration     1258
# ProductRelated              311
# ProductRelated_Duration    9551
# BounceRates                1872
# ExitRates                  4777
# PageValues                 2704
# SpecialDay                    6
# Month                        10
# OperatingSystems              8
# Browser                      13
# Region                        9
# TrafficType                  20
# VisitorType                   3
# Weekend                       2
# Revenue                       2
# dtype: int64

# %%
tf_df["TrafficType"].value_counts()
traffic_type_to_replace = list(tf_df['TrafficType'].value_counts()[tf_df['TrafficType'].value_counts() < 200].index)

# Replace in dataframe
for type in traffic_type_to_replace:
    tf_df['TrafficType'] = tf_df['TrafficType'].replace(type,"Other")

# Check to make sure replacement was successful
tf_df['TrafficType'].value_counts()
# Out:
# TrafficType
# 2        3913
# 1        2451
# 3        2052
# 4        1069
# 13        738
# 10        450
# 6         444
# Other     363
# 8         343
# 5         260
# 11        247
# Name: count, dtype: int64

# %%
tf_df['ProductRelated'].value_counts()[tf_df['ProductRelated'].value_counts() > 1]
product_to_replace = list(tf_df['ProductRelated'].value_counts()[tf_df['ProductRelated'].value_counts() < 200].index)

# Replace in dataframe
for type in product_to_replace:
    tf_df['ProductRelated'] = tf_df['ProductRelated'].replace(type,"Other")

# Check to make sure replacement was successful
tf_df['ProductRelated'].value_counts()
# Out:
# ProductRelated
# Other    5422
# 1         622
# 2         465
# 3         458
# 4         404
# 6         396
# 7         391
# 5         382
# 8         370
# 10        330
# 9         317
# 12        313
# 11        308
# 13        289
# 15        270
# 16        260
# 14        251
# 17        226
# 20        225
# 19        218
# 22        213
# 18        200
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummy_df = pd.get_dummies(tf_df, columns=["ProductRelated", "Month", "OperatingSystems", "Browser", "Region", "TrafficType", "VisitorType"], drop_first=True)
dummy_df.head()
# Out:
#    Administrative  ...  VisitorType_Returning_Visitor
# 0               0  ...                           True
# 1               0  ...                           True
# 2               0  ...                           True
# 3               0  ...                           True
# 4               0  ...                           True
#
# [5 rows x 80 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = dummy_df.drop(columns=["Revenue"]).values
y = dummy_df["Revenue"]
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
tf_model = tf.keras.models.Sequential()

# %%
tf_model.add(tf.keras.Input(shape=((X_train_scaled.shape[1],))))
tf_model.add(tf.keras.layers.Dense(64, activation='relu'))
tf_model.add(tf.keras.layers.Dense(32, activation='relu'))
tf_model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
tf_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 64)                5120
#
#  dense_14 (Dense)            (None, 32)                2080
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 7,233
# Trainable params: 7,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
tf_model.fit(X_train_scaled, y_train, epochs=200, batch_size=1024)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6301 - accuracy: 0.6553
# Epoch 2/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4543 - accuracy: 0.8437
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4157 - accuracy: 0.8454
# Epoch 4/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3890 - accuracy: 0.8462
# Epoch 5/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3671 - accuracy: 0.8484
# Epoch 6/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3508 - accuracy: 0.8536
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3375 - accuracy: 0.8568
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3261 - accuracy: 0.8606
# Epoch 9/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3160 - accuracy: 0.8681
# Epoch 10/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3077 - accuracy: 0.8726
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3005 - accuracy: 0.8750
# Epoch 12/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2936 - accuracy: 0.8766
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2877 - accuracy: 0.8802
# Epoch 14/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2817 - accuracy: 0.8853
# Epoch 15/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2770 - accuracy: 0.8860
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2733 - accuracy: 0.8864
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.8887
# Epoch 18/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2657 - accuracy: 0.8906
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2624 - accuracy: 0.8917
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2588 - accuracy: 0.8935
# Epoch 21/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2564 - accuracy: 0.8923
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2537 - accuracy: 0.8950
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2507 - accuracy: 0.8978
# Epoch 24/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2484 - accuracy: 0.8972
# Epoch 25/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2460 - accuracy: 0.8986
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2440 - accuracy: 0.8981
# Epoch 27/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2419 - accuracy: 0.8987
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2395 - accuracy: 0.9018
# Epoch 29/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2372 - accuracy: 0.9009
# Epoch 30/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2353 - accuracy: 0.9022
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2340 - accuracy: 0.9025
# Epoch 32/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2320 - accuracy: 0.9032
# Epoch 33/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2303 - accuracy: 0.9047
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2284 - accuracy: 0.9041
# Epoch 35/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.9065
# Epoch 36/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2264 - accuracy: 0.9061
# Epoch 37/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2236 - accuracy: 0.9063
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2215 - accuracy: 0.9076
# Epoch 39/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2190 - accuracy: 0.9074
# Epoch 40/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2169 - accuracy: 0.9083
# Epoch 41/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2150 - accuracy: 0.9091
# Epoch 42/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9093
# Epoch 43/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2113 - accuracy: 0.9102
# Epoch 44/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2101 - accuracy: 0.9097
# Epoch 45/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2087 - accuracy: 0.9106
# Epoch 46/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2071 - accuracy: 0.9119
# Epoch 47/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2060 - accuracy: 0.9125
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.9141
# Epoch 49/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2043 - accuracy: 0.9128
# Epoch 50/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2023 - accuracy: 0.9132
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2017 - accuracy: 0.9109
# Epoch 52/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2000 - accuracy: 0.9132
# Epoch 53/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1979 - accuracy: 0.9150
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1962 - accuracy: 0.9156
# Epoch 55/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1961 - accuracy: 0.9131
# Epoch 56/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1978 - accuracy: 0.9182
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1945 - accuracy: 0.9155
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1938 - accuracy: 0.9166
# Epoch 59/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1930 - accuracy: 0.9189
# Epoch 60/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1904 - accuracy: 0.9152
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1883 - accuracy: 0.9186
# Epoch 62/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1875 - accuracy: 0.9181
# Epoch 63/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1862 - accuracy: 0.9189
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 0.9192
# Epoch 65/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1839 - accuracy: 0.9194
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1826 - accuracy: 0.9208
# Epoch 67/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1819 - accuracy: 0.9204
# Epoch 68/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1799 - accuracy: 0.9225
# Epoch 69/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1787 - accuracy: 0.9230
# Epoch 70/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1769 - accuracy: 0.9220
# Epoch 71/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1754 - accuracy: 0.9239
# Epoch 72/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1748 - accuracy: 0.9245
# Epoch 73/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1734 - accuracy: 0.9248
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1722 - accuracy: 0.9253
# Epoch 75/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1717 - accuracy: 0.9251
# Epoch 76/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1704 - accuracy: 0.9257
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.9271
# Epoch 78/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1687 - accuracy: 0.9262
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1680 - accuracy: 0.9267
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1662 - accuracy: 0.9292
# Epoch 81/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1645 - accuracy: 0.9306
# Epoch 82/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.9286
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1644 - accuracy: 0.9292
# Epoch 84/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1637 - accuracy: 0.9282
# Epoch 85/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1626 - accuracy: 0.9298
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9282
# Epoch 87/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1601 - accuracy: 0.9298
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1580 - accuracy: 0.9332
# Epoch 89/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1574 - accuracy: 0.9321
# Epoch 90/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1573 - accuracy: 0.9326
# Epoch 91/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1549 - accuracy: 0.9328
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9338
# Epoch 93/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1543 - accuracy: 0.9322
# Epoch 94/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1566 - accuracy: 0.9325
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1550 - accuracy: 0.9325
# Epoch 96/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1532 - accuracy: 0.9337
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9348
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1519 - accuracy: 0.9336
# Epoch 99/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1498 - accuracy: 0.9336
# Epoch 100/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.9367
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1483 - accuracy: 0.9345
# Epoch 102/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1468 - accuracy: 0.9349
# Epoch 103/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9352
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1450 - accuracy: 0.9376
# Epoch 105/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1453 - accuracy: 0.9380
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1459 - accuracy: 0.9359
# Epoch 107/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1448 - accuracy: 0.9390
# Epoch 108/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1452 - accuracy: 0.9363
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9398
# Epoch 110/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1415 - accuracy: 0.9402
# Epoch 111/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1389 - accuracy: 0.9408
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1379 - accuracy: 0.9419
# Epoch 113/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1375 - accuracy: 0.9398
# Epoch 114/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1358 - accuracy: 0.9431
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.9435
# Epoch 116/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1354 - accuracy: 0.9411
# Epoch 117/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1345 - accuracy: 0.9410
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9446
# Epoch 119/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1348 - accuracy: 0.9432
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1332 - accuracy: 0.9444
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1340 - accuracy: 0.9439
# Epoch 122/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1330 - accuracy: 0.9414
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.9451
# Epoch 124/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1288 - accuracy: 0.9442
# Epoch 125/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1279 - accuracy: 0.9434
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9464
# Epoch 127/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1254 - accuracy: 0.9466
# Epoch 128/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1244 - accuracy: 0.9464
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.9497
# Epoch 130/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.9486
# Epoch 131/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.9479
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.9503
# Epoch 133/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1235 - accuracy: 0.9486
# Epoch 134/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1227 - accuracy: 0.9493
# Epoch 135/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1235 - accuracy: 0.9450
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9507
# Epoch 137/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1204 - accuracy: 0.9472
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9501
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9510
# Epoch 140/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1167 - accuracy: 0.9526
# Epoch 141/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1163 - accuracy: 0.9520
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9531
# Epoch 143/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1190 - accuracy: 0.9470
# Epoch 144/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1161 - accuracy: 0.9530
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1155 - accuracy: 0.9526
# Epoch 146/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1178 - accuracy: 0.9525
# Epoch 147/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1148 - accuracy: 0.9520
# Epoch 148/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1122 - accuracy: 0.9538
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.9545
# Epoch 150/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.9552
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9563
# Epoch 152/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9543
# Epoch 153/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1125 - accuracy: 0.9570
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9508
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1086 - accuracy: 0.9557
# Epoch 156/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1078 - accuracy: 0.9559
# Epoch 157/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1067 - accuracy: 0.9569
# Epoch 158/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1073 - accuracy: 0.9571
# Epoch 159/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1070 - accuracy: 0.9565
# Epoch 160/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9578
# Epoch 161/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1038 - accuracy: 0.9587
# Epoch 162/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1029 - accuracy: 0.9585
# Epoch 163/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1012 - accuracy: 0.9597
# Epoch 164/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1009 - accuracy: 0.9607
# Epoch 165/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1014 - accuracy: 0.9602
# Epoch 166/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0993 - accuracy: 0.9612
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9600
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1020 - accuracy: 0.9600
# Epoch 169/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9587
# Epoch 170/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1005 - accuracy: 0.9602
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0982 - accuracy: 0.9611
# Epoch 172/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0971 - accuracy: 0.9614
# Epoch 173/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0969 - accuracy: 0.9618
# Epoch 174/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0988 - accuracy: 0.9601
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9633
# Epoch 176/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0952 - accuracy: 0.9636
# Epoch 177/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9625
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9602
# Epoch 179/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0961 - accuracy: 0.9619
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9604
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0959 - accuracy: 0.9640
# Epoch 182/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9615
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0930 - accuracy: 0.9625
# Epoch 184/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0910 - accuracy: 0.9654
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9629
# Epoch 186/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0909 - accuracy: 0.9634
# Epoch 187/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0906 - accuracy: 0.9651
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9613
# Epoch 189/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0903 - accuracy: 0.9680
# Epoch 190/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0877 - accuracy: 0.9665
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.9660
# Epoch 192/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0871 - accuracy: 0.9669
# Epoch 193/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0860 - accuracy: 0.9677
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0853 - accuracy: 0.9681
# Epoch 195/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0869 - accuracy: 0.9660
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9659
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 0.9655
# Epoch 198/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0867 - accuracy: 0.9673
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0840 - accuracy: 0.9682
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9694

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = tf_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 97/97 - 0s - loss: 0.4528 - accuracy: 0.8667 - 352ms/epoch - 4ms/step
# Loss: 0.45277291536331177, Accuracy: 0.8666883111000061

# %%
# Classification report
from sklearn.metrics import classification_report
import numpy as np

# Get predicted probabilities and convert to class labels (0 or 1)
y_pred_probs = tf_model.predict(X_test_scaled)
y_pred = np.round(y_pred_probs).astype(int)  # Apply 0.5 threshold

# Generate classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 97/97 [==============================] - 0s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.91      0.94      0.92      2606
#         True       0.59      0.47      0.52       477
#
#     accuracy                           0.87      3083
#    macro avg       0.75      0.70      0.72      3083
# weighted avg       0.86      0.87      0.86      3083
